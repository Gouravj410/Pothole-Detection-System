# %%
from getpass import getpass

username = "Gouravj410"
token = getpass("Enter your GitHub token: ")

# !git clone https://{username}:{token}@github.com/{username}/Pothole-Detection-System.git
# %cd Pothole-Detection-System
# Out:
# Enter your GitHub token: ··········
# Cloning into 'Pothole-Detection-System'...
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 7 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (7/7), done.
# /content/Pothole-Detection-System

# %%
import shutil

# replace 'training_model.ipynb' with your notebook name
shutil.copy("/content/PDS.ipynb", "/content/Pothole-Detection-System/")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2745786247.py in <cell line: 0>()
#       2
#       3 # replace 'training_model.ipynb' with your notebook name
# ----> 4 shutil.copy("/content/PDS.ipynb", "/content/Pothole-Detection-System/")
#
# /usr/lib/python3.12/shutil.py in copy(src, dst, follow_symlinks)
#     433     if os.path.isdir(dst):
#     434         dst = os.path.join(dst, os.path.basename(src))
# --> 435     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     436     copymode(src, dst, follow_symlinks=follow_symlinks)
#     437     return dst
#
# /usr/lib/python3.12/shutil.py in copyfile(src, dst, follow_symlinks)
#     258         os.symlink(os.readlink(src), dst)
#     259     else:
# --> 260         with open(src, 'rb') as fsrc:
#     261             try:
#     262                 with open(dst, 'wb') as fdst:
#
# ...

# %%
# !nvidia-smi
# Out:
# Tue Sep  2 14:52:53 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8             11W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !unzip -q /content/dataset.zip -d /content/dataset

# %%
# !ls /content/dataset/images | head
# !ls /content/dataset/labels | head
# Out:
# potholes0.png
# potholes100.png
# potholes101.png
# potholes102.png
# potholes103.png
# potholes104.png
# potholes105.png
# potholes106.png
# potholes107.png
# potholes108.png
# potholes0.txt
# potholes100.txt
# potholes101.txt
# potholes102.txt
# potholes103.txt
# potholes104.txt
# potholes105.txt
# potholes106.txt
# potholes107.txt
# potholes108.txt

# %%
import os, random, shutil

random.seed(42)

images_dir = "/content/dataset/images"
labels_dir = "/content/dataset/labels"
output_dir = "/content/dataset/pothole_dataset_split"

# %%
#Make folder
for sub in ["images/train", "images/val", "labels/train", "labels/val"]:
  os.makedirs(os.path.join(output_dir, sub), exist_ok=True)

# %%
#List images
images = [f for f in os.listdir(images_dir) if f.endswith((".jpg", ".png", ".jpeg"))]
random.shuffle(images)

# %%
#Split 80/20
split_idx = int(0.8 * len(images))
train_imgs, val_imgs = images[:split_idx], images[split_idx:]

def move_files(img_list, subset):
  for img in img_list:
    base = os.path.splitext(img)[0]
    label = base + ".txt"
    shutil.copy(os.path.join(images_dir, img), os.path.join(output_dir, f"images/{subset}", img))
    shutil.copy(os.path.join(labels_dir, label), os.path.join(output_dir, f"labels/{subset}", label))

move_files(train_imgs, "train")
move_files(val_imgs, "val")

print(f"Done: {len(train_imgs)} train, {len(val_imgs)} val")
# Out:
# Done: 532 train, 133 val

# %%
#Read Class
with open("/content/dataset/classes.txt", "r") as f:
  classes = [c.strip() for c in f.readlines()]

yaml_content = f"""
train: {os.path.join(output_dir, "images/train")}
val: {os.path.join(output_dir, "images/val")}

nc: {len(classes)}
names: {classes}
"""
# Out:
# Done: 532 train, 133 val
